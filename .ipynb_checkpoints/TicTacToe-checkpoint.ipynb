# %%
def player_input():
    
    print('Welcome to Tic Tac Toe!')
    
    player1_name_input = input('Player 1, please enter your name: ')
    player1_name.append(player1_name_input)
    
    player2_name_input = input('Player 2, please enter your name: ')
    player2_name.append(player2_name_input)
    
    marker = ''
    
    #Keep asking player 1 to choose X or O
    while marker != 'X' and marker != 'O':
        marker = input(player1_name_input + ', please choose X or O: ')
        
    #Assign player 2 the opposite marker
    player1 = marker
    
    if player1 =='X':
        player2 = 'O'
    elif player1 == 'O':
        player2 ='X'

    player1_choice.append(player1)
    player2_choice.append(player2)
    
    print(player1_name_input + ' has selected ' + player1 + '.')
    print(player2_name_input + ' will be ' + player2 + '.')

# %%
from IPython.display import clear_output

def display_board(board):      
    print(board[7]+'|'+board[8]+'|'+board[9])
    print('-|-|-')
    print(board[4]+'|'+board[5]+'|'+board[6])
    print('-|-|-')
    print(board[1]+'|'+board[2]+'|'+board[3])

# %%
def position_choice():

    choice ='WRONG'
    within_range = False
    
    while choice.isdigit() == False or within_range == False:
    
        choice = input("Please enter a number (1-9): ")
        
        if choice.isdigit() == False:
            print("Sorry that is not a digit!")
            
        if choice.isdigit() == True:
            if int(choice) in range(0,10):
                within_range = True
            else:
                within_range = False
                print("Sorry that number is not in range!")
        if choice in position_picked:
            print("Sorry, position has already been picked! ")
            
    while choice in position_picked or choice.isdigit() == False or within_range == False:

        choice = input("Please enter a number (1-9): ")
        
        if choice in position_picked:
            print("Sorry, position has already been picked! ")
            
        if choice.isdigit() == False:
            print("Sorry that is not a digit!")

        if choice.isdigit() == True:
            if int(choice) in range(0,10):
                within_range = True
            else:
                within_range = False
                print("Sorry that number is not in range!")
            
    position_picked.append(choice)    
    
    return int(choice)

# %%
def replacement_choice(game_list, position):    
    
    user_placement = 'WRONG'
    
    while user_placement != player1_choice[0] and x%2 != 0:
    
        user_placement = input("Type a string to place at that position: ")

        if user_placement not in ['X','O']:
            print('Please enter a valid character')
            
        if x%2 != 0 and user_placement == player2_choice[0]:
            print("Incorrect choice. Please choose " + player1_choice[0] + ".")
        
        elif x%2 == 0 and user_placement == player1_choice[0]:
            print("Incorrect choice. Please choose " + player2_choice[0] + ".")
        else:
            pass
        
    while user_placement != player2_choice[0] and x%2 == 0:
    
        user_placement = input("Type a string to place at that position: ")

        if user_placement not in ['X','O']:
            print('Please enter a valid character')
            
        if x%2 != 0 and user_placement == player2_choice[0]:
            print("Incorrect choice. Please choose " + player1_choice[0] + ".")
        
        elif x%2 == 0 and user_placement == player1_choice[0]:
            print("Incorrect choice. Please choose " + player2_choice[0] + ".")
        else:
            pass
                   
    game_list[position] = user_placement
    
    return game_list

# %%
def gameon_choice():
    
    choice = 'wrong'
    
    while choice not in ['Y','N']:
    
        choice = input("Keep playing? (Y or N): ")
        
        if choice not in ['Y','N']:
            print("Sorry, I don't understand, please choose Y or N ")
    
    if choice == 'Y':
        return True
    else:
        return False

# %%
import sys
def win_check():
    game_over = False
    if x%2 != 0:
        if (game_list[1] == player1_choice[0] and game_list[2] == player1_choice[0] and game_list[3] == player1_choice[0]):
            print(player1_name[0] + ' has won!')
            game_over = True
        elif (game_list[4] == player1_choice[0] and game_list[5] == player1_choice[0] and game_list[6] == player1_choice[0]):            
            print(player1_name[0] + ' has won!')
            game_over = True
        elif (game_list[7] == player1_choice[0] and game_list[8] == player1_choice[0] and game_list[9] == player1_choice[0]): 
            print(player1_name[0] + ' has won!')
            game_over = True  
        elif (game_list[1] == player1_choice[0] and game_list[4] == player1_choice[0] and game_list[7] == player1_choice[0]):
            print(player1_name[0] + ' has won!')
            game_over = True
        elif (game_list[2] == player1_choice[0] and game_list[5] == player1_choice[0] and game_list[8] == player1_choice[0]):
            print(player1_name[0] + ' has won!')
            game_over = True
        elif (game_list[3] == player1_choice[0] and game_list[6] == player1_choice[0] and game_list[9] == player1_choice[0]): 
            print(player1_name[0] + ' has won!')
            game_over = True  
        elif (game_list[1] == player1_choice[0] and game_list[5] == player1_choice[0] and game_list[9] == player1_choice[0]):
            print(player1_name[0] + ' has won!')
            game_over = True    
        elif (game_list[3] == player1_choice[0] and game_list[5] == player1_choice[0] and game_list[7] == player1_choice[0]):
            print(player1_name[0] + ' has won!')
            game_over = True
            

    elif x%2 == 0:
        if (game_list[1] == player2_choice[0] and game_list[2] == player2_choice[0] and game_list[3] == player2_choice[0]):
            print(player2_choice[0] + ' has won!')
            game_over = True
        elif (game_list[4] == player2_choice[0] and game_list[5] == player2_choice[0] and game_list[6] == player2_choice[0]):            
            print(player2_choice[0] + ' has won!')
            game_over = True
        elif (game_list[7] == player2_choice[0] and game_list[8] == player2_choice[0] and game_list[9] == player2_choice[0]): 
            print(player2_choice[0] + ' has won!')
            game_over = True  
        elif (game_list[1] == player2_choice[0] and game_list[4] == player2_choice[0] and game_list[7] == player2_choice[0]):
            print(player2_choice[0] + ' has won!')
            game_over = True
        elif (game_list[2] == player2_choice[0] and game_list[5] == player2_choice[0] and game_list[8] == player2_choice[0]):
            print(player2_choice[0] + ' has won!')
            game_over = True
        elif (game_list[3] == player2_choice[0] and game_list[6] == player2_choice[0] and game_list[9] == player2_choice[0]): 
            print(player2_choice[0] + ' has won!')
            game_over = True  
        elif (game_list[1] == player2_choice[0] and game_list[5] == player2_choice[0] and game_list[9] == player2_choice[0]):
            print(player2_choice[0] + ' has won!')
            game_over = True 
        elif (game_list[3] == player2_choice[0] and game_list[5] == player2_choice[0] and game_list[7] == player2_choice[0]):
            print(player2_choice[0] + ' has won!')
            game_over = True
    if game_over == True:
        sys.exit()
    else:
        return False

# %%
game_on = True
game_list = ['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']
player_turns = [1,2,3,4,5,6,7,8,9]
position_picked = []
player2_choice = []
player1_choice = []
player1_name = []
player2_name = []

player_input()

for x in player_turns:

    if x%2 != 0:

        print(player1_name[0] + ", please make your move.")
        
        turn = False        
        while game_on and turn == False:
            
            position = position_choice()

            game_list = replacement_choice(game_list,position)

            game_on = gameon_choice()

            clear_output()

            display_board(game_list)
            
            win_check()
            
            turn = True
    else:
    
        print(player2_name[0] + ", please make your move.")
        
        turn = False       
        while game_on and turn == False:
            
            position = position_choice()

            game_list = replacement_choice(game_list,position)

            game_on = gameon_choice()

            clear_output()

            display_board(game_list)
            
            win_check()
         
            turn = True
# Out:
# X| |O
# -|-|-
# X|O|
# -|-|-
# X| |
# n has won!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
